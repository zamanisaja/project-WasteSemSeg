# %% [markdown]
# # New Section

# %%
import os
import random

import torch
from torch import optim
from torch.autograd import Variable
from torch.nn import NLLLoss2d
from torch.optim.lr_scheduler import StepLR
from torchvision.utils import save_image
import torchvision.transforms as standard_transforms
import torchvision.utils as vutils

from tensorboardX import SummaryWriter
import pdb

# %%
from model import ENet
from config import cfg
from loading_data import loading_data
from utils import *
from timer import Timer

# %%
exp_name = cfg.TRAIN.EXP_NAME
log_txt = cfg.TRAIN.EXP_LOG_PATH + '/' + exp_name + '.txt'
writer = SummaryWriter(cfg.TRAIN.EXP_PATH+ '/' + exp_name)

pil_to_tensor = standard_transforms.ToTensor()
train_loader, val_loader, restore_transform = loading_data()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-7fbe5d0056d6> in <cell line: 6>()
#       4
#       5 pil_to_tensor = standard_transforms.ToTensor()
# ----> 6 train_loader, val_loader, restore_transform = loading_data()
#
# /content/loading_data.py in loading_data()
#      29     ])
#      30
# ---> 31     train_set = resortit('train', simul_transform=train_simul_transform, transform=img_transform,
#      32                            target_transform=target_transform)
#      33     train_loader = DataLoader(train_set, batch_size=cfg.TRAIN.BATCH_SIZE, num_workers=16, shuffle=True)
#
# /content/resortit.py in __init__(self, mode, simul_transform, transform, target_transform)
#      35 class resortit(data.Dataset):
#      36     def __init__(self, mode, simul_transform=None, transform=None, target_transform=None):
# ---> 37         self.imgs = make_dataset(mode)
#      38         if len(self.imgs) == 0:
#      39             raise (RuntimeError('Found 0 images, please check the data set'))
#
# /content/resortit.py in make_dataset(mode)
#      19         processed_train_img_path = processed_train_path
#      20         processed_train_mask_path = cfg.DATA.DATA_PATH
# ---> 21         for img_name in os.listdir(processed_train_img_path):
#      22             item = (os.path.join(processed_train_img_path, img_name),
#      23                     os.path.join(processed_train_mask_path + '/labels/train/', img_name))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/synthetic_single_dataset/train'

# %%
# %pwd

# %%
cfg
